# %% [markdown]
# # Proyecto Final
# by Matías Moré

# %%
#Librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_palette(["#024059", "#66D9CD", "#D9923B", "#BF726B", "#401F1F"])

# %% [markdown]
# ## Dataset Fumadores

# %% [markdown]
# Este conjunto de datos consiste en datos biologicos de distintos individuos, recolectados con el objetivo de analizar los efectos y las señales del habito tabaquico. A travez de distintas caracteristicas de estudios de laboratorio como el estado sanguineo, urinario, hepatico, higienico y su relacion con el tabaquismo, se buscara encontrar patrones que determinen biologicamente los parametros a tener en cuenta para identificar a individuos fumadores. Teniendo en cuenta estos datos se realizara una comparacion de estas variables a fin de determinar su utilidad y trascendencia para lograr este fin.
#
# Origen del dataset: https://www.kaggle.com/datasets/kukuroo3/body-signal-of-smoking?resource=download

# %% [markdown]
# ### Code Acquisition

# %%
smoke_data = pd.read_csv('/workspaces/CoderPosta/Data/smoking.csv')
smoke_data
# Out:
#           ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0          0      F   40         155          60       81.3             1.2
# 1          1      F   40         160          60       81.0             0.8
# 2          2      M   55         170          60       80.0             0.8
# 3          3      M   40         165          70       88.0             1.5
# 4          4      F   40         155          60       86.0             1.0
# ...      ...    ...  ...         ...         ...        ...             ...
# 55687  55676      F   40         170          65       75.0             0.9
# 55688  55681      F   45         160          50       70.0             1.2
# 55689  55683      F   55         160          50       68.5             1.0
# 55690  55684      M   60         165          60       78.0             0.8
# 55691  55691      M   55         160          65       85.0             0.9
#
# ...

# %% [markdown]
# ## Dataset Causas de Muerte

# %% [markdown]
# El archivo de datos presentado contiene datos históricos sobre las diferentes causas de muerte en todas las edades en todo el mundo. Los principales aspectos del conjunto de datos son: meningitis, enfermedad de Alzheimer y otras demencias, enfermedad de Parkinson, carencias nutricionales, malaria, ahogamiento, violencia interpersonal, trastornos maternos, VIH / SIDA, trastornos relacionados con el uso de drogas, tuberculosis, enfermedades cardiovasculares, infecciones respiratorias bajas, trastornos neonatales, trastornos relacionados con el uso de alcohol, auto daño, exposición a las fuerzas de la naturaleza, enfermedades diarreicas, exposición al calor y frío ambiental, neoplasias, conflicto y terrorismo, diabetes mellitus, enfermedad renal crónica, envenenamientos, malnutrición proteico-energética, lesiones en carretera, enfermedades respiratorias crónicas, cirrosis y otras enfermedades hepáticas crónicas, enfermedades digestivas, fuego, calor y sustancias calientes, hepatitis aguda.
# Este conjunto de datos permite detectar tendencias en las causas de muerte a nivel mundial, utilizando metricas como DALY (Años de Vida Ajustados por Discapacidad), podriamos comparar la carga de enfermedad de diferentes enfermedades en diferentes países, entre diferentes poblaciones y en diferentes momentos.
#
# Origen del database: https://www.kaggle.com/datasets/iamsouravbanerjee/cause-of-deaths-around-the-world

# %% [markdown]
# ### Code Acquisition

# %%
cod_data = pd.read_csv('/workspaces/CoderPosta/Data/cause_of_deaths.csv')
cod_data
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %% [markdown]
# ## Dataset Juegos de Mesa

# %% [markdown]
# Esta base de datos contiene información recolectada sobre juegos de mesa de la página web BoardGameGeek (BGG) en febrero de 2021, que incluye calificaciones, reseñas y discusiones de los juegos. Este conjunto de datos es valioso como herramienta para analizar tendencias en el mercado de juegos de mesa y ayudar en la toma de decisiones estratégicas para el diseño y mejora de juegos de mesa.
#
# Origen del database: https://www.kaggle.com/datasets/andrewmvd/board-games

# %% [markdown]
# ### Code Acquisition

# %%
bbg_data = pd.read_csv('/workspaces/CoderPosta/Data/bgg_dataset.csv', delimiter=';', encoding='utf-8')
bbg_data
# Out:
#              ID                               Name  Year Published  \
# 0      174430.0                         Gloomhaven          2017.0
# 1      161936.0          Pandemic Legacy: Season 1          2015.0
# 2      224517.0                  Brass: Birmingham          2018.0
# 3      167791.0                  Terraforming Mars          2016.0
# 4      233078.0  Twilight Imperium: Fourth Edition          2017.0
# ...         ...                                ...             ...
# 20338   16398.0                                War             0.0
# 20339    7316.0                              Bingo          1530.0
# 20340    5048.0                         Candy Land          1949.0
# 20341    5432.0                 Chutes and Ladders          -200.0
# 20342   11901.0                        Tic-Tac-Toe         -1300.0
#
#        Min Players  Max Players  Play Time  Min Age  Users Rated  \
# 0                1            4        120       14        42055
# ...

# %% [markdown]
# # Analisis de Datos

# %% [markdown]
# ### Generacion de la variable IMC

# %%
df = smoke_data.copy()
df["height(M)"] = df["height(cm)"] / 100
df["IMC"] = df["weight(kg)"] / (df["height(M)"] ** 2)
df
# Out:
#           ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0          0      F   40         155          60       81.3             1.2
# 1          1      F   40         160          60       81.0             0.8
# 2          2      M   55         170          60       80.0             0.8
# 3          3      M   40         165          70       88.0             1.5
# 4          4      F   40         155          60       86.0             1.0
# ...      ...    ...  ...         ...         ...        ...             ...
# 55687  55676      F   40         170          65       75.0             0.9
# 55688  55681      F   45         160          50       70.0             1.2
# 55689  55683      F   55         160          50       68.5             1.0
# 55690  55684      M   60         165          60       78.0             0.8
# 55691  55691      M   55         160          65       85.0             0.9
#
# ...

# %% [markdown]
# ### Visualizacion IMC

# %%
# Crear histograma para no fumadores
df[df['smoking'] == 0]['IMC'].plot.hist(bins=20, edgecolor='black', alpha = 0.5, label='No Fumadores')

# Crear histograma para fumadores
df[df['smoking'] == 1]['IMC'].plot.hist(bins=20, edgecolor='black', alpha = 0.5, label='Fumadores')



# Añadir etiquetas al eje x e y
plt.xlabel('IMC')
plt.ylabel('Población')

# Añadir un título al gráfico
plt.title('IMC de Fumadores y No Fumadores')

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
# Crear una tabla de frecuencia cruzada entre la edad y el estado de fumador
cross_table = pd.crosstab(df['age'], df['smoking'])

# Graficar la tabla de frecuencia cruzada para fumadores
plt.plot(cross_table[1])
plt.xlabel('Edad')
plt.ylabel('Población')
plt.title('Prevalencia de Tabaquismo según la Edad')
plt.show()

# %%
df[["eyesight(left)","eyesight(right)"]].describe()
# Out:
#        eyesight(left)  eyesight(right)
# count    55692.000000     55692.000000
# mean         1.012623         1.007443
# std          0.486873         0.485964
# min          0.100000         0.100000
# 25%          0.800000         0.800000
# 50%          1.000000         1.000000
# 75%          1.200000         1.200000
# max          9.900000         9.900000

# %%
plt.scatter(df['eyesight(left)'], df['eyesight(right)'])
plt.xlabel('Vision Ojo Izquierdo')
plt.ylabel('Vision ojo Derecho')
plt.title('Correlación entre Ojo Derecho y Ojo Izquierdo')
plt.show()

# %%
df[["Cholesterol","HDL","LDL"]].describe()
# Out:
#         Cholesterol           HDL           LDL
# count  55692.000000  55692.000000  55692.000000
# mean     196.901422     57.290347    114.964501
# std       36.297940     14.738963     40.926476
# min       55.000000      4.000000      1.000000
# 25%      172.000000     47.000000     92.000000
# 50%      195.000000     55.000000    113.000000
# 75%      220.000000     66.000000    136.000000
# max      445.000000    618.000000   1860.000000

# %%
sns.boxplot(x="smoking", y="LDL", data=df)
# Out:
# <AxesSubplot: xlabel='smoking', ylabel='LDL'>
